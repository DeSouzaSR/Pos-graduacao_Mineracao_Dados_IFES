# %% [markdown]
# # Atividade prática - Introdução
# A atividade sugerida faz uso dos dados de uma base modifica [IGM - Índice Governança Municipal](https://www.kaggle.com/datasets/joaoavf/igm-indice-governancao-municipal). Os dados foram alterados e simplificados pelo professor da disciplina

# %% [markdown]
# # Imports

# %%
import pandas as pd
pd.set_option("display.max_columns", 500)

# %% [markdown]
# # Leitura e apresentação dos dados

# %%
caminho_csv = '../../datasets/igm_modificado.csv'
dataframe = pd.read_csv(caminho_csv, sep=',', encoding='utf-8', thousands=',')
dataframe.head()
# Out:
#          regiao estado              municipio  codigo_mun  capital  \
# 0       SUDESTE     SP               ILHABELA     3520400        0
# 1       SUDESTE     SP    SANTANA DE PARNAIBA     3547304        0
# 2           SUL     SC              BOMBINHAS     4202453        0
# 3       SUDESTE     SP  SAO BERNARDO DO CAMPO     3548708        0
# 4  CENTRO-OESTE     DF               BRASILIA     5300108        1
#
#              porte  populacao     area  densidade_dem           pib  \
# 0  Pequeno porte 2     32,782   347.52           81.1  3.256712e+06
# 1     Grande porte    129,261   179.95          604.7  7.373603e+06
# 2  Pequeno porte 1     18,052    35.92          398.0  3.773573e+05
# 3     Grande porte    822,242   409.53         1869.4  4.766853e+07
# 4     Grande porte  2,977,216  5780.00          444.7  1.753628e+08
#
#       pib_pc  participacao_transf_receita  servidores  comissionados  \
# 0  105112.86                         77.0      1495.0           74.0
# ...

# %% [markdown]
# Quantos linhas e colunas?

# %%
print(f'Linhas: {dataframe.shape[0]}\nColunas: {dataframe.shape[1]}')
# Out:
# Linhas: 5570
# Colunas: 32

# %%
dataframe.describe()
# Out:
#          codigo_mun      capital           area  densidade_dem           pib  \
# count  5.570000e+03  5570.000000    5570.000000    5566.000000  5.570000e+03
# mean   3.253591e+06     0.004847    1526.532426     108.189026  9.544801e+05
# std    9.849103e+05     0.069461    5607.553417     572.067148  9.502661e+06
# min    1.100015e+06     0.000000       3.570000       0.100000  9.678440e+03
# 25%    2.512126e+06     0.000000     204.245000      11.600000  5.922529e+04
# 50%    3.146280e+06     0.000000     417.980000      24.400000  1.301531e+05
# 75%    4.119190e+06     0.000000    1026.165000      51.700000  3.426808e+05
# max    5.300108e+06     1.000000  159533.260000   13024.600000  5.707062e+08
#
#               pib_pc  participacao_transf_receita     servidores  \
# count    5570.000000                  4893.000000    5233.000000
# mean    17374.483108                    82.316575     771.324861
# std     20133.341193                    11.272136    3209.755931
# ...

# %% [markdown]
# # Dados do Espírito Santo

# %%
dataframe_es = dataframe[dataframe['estado'] == 'ES']
dataframe_es.head()
# Out:
#       regiao estado   municipio  codigo_mun  capital            porte  \
# 14   SUDESTE     ES     VITORIA     3205309        1     Grande porte
# 79   SUDESTE     ES     ARACRUZ     3200607        0      Médio porte
# 93   SUDESTE     ES       PIUMA     3204203        0  Pequeno porte 2
# 174  SUDESTE     ES    LINHARES     3203205        0     Grande porte
# 227  SUDESTE     ES  MARATAIZES     3203320        0  Pequeno porte 2
#
#     populacao     area  densidade_dem          pib     pib_pc  \
# 14    359,555    96.54         3338.3  22289815.47   64001.91
# 79     96,746  1423.87           57.5   5214973.56   56955.65
# 93     21,030    74.82          242.2    446855.58   22251.55
# 174   166,491  3504.14           40.3   5178698.58   32815.20
# 227    38,301   133.08          256.6   4501549.26  121204.88
#
#      participacao_transf_receita  servidores  comissionados  \
# 14                          49.0     10031.0          713.0
# ...

# %%
dataframe_es.shape
# Out:
# (78, 32)

# %% [markdown]
# Podemos observar na saida acima que, de fato, temos 78 municípios

# %% [markdown]
# # Agrupando os dados por região

# %%
grupos_regiao = dataframe.groupby('regiao')
grupos_regiao

# %%
print(len(grupos_regiao))
# Out:
# 5

# %%
for regiao, dataframe_regiao in grupos_regiao:
    media_nota_redacao = dataframe_regiao['nota_redacao'].mean() # Cálculo da média
    desvio_padrao_nota_redacao = dataframe_regiao['nota_redacao'].std() # Cálculo do desvio padrão
    menor_nota = dataframe_regiao['nota_redacao'].min()
    maior_nota = dataframe_regiao['nota_redacao'].max()
    amplitude = maior_nota - menor_nota

    #print(f'\nRegião: {regiao} {len(dataframe_regiao)}')
    print(regiao)
    print(f'{"Quantidade de dados":<30}{len(dataframe_regiao):>7d}')
    print(f'{"Média Nota Redação":<30} {media_nota_redacao:>6.2f}')
    print(f'{"Desvio Padrão Nota Redação":<30} {desvio_padrao_nota_redacao:>6.2f}')
    print(f'{"Menor Nota Redação":<30} {menor_nota:>6.2f}')
    print(f'{"Maior Nota Redação":<30} {maior_nota:>6.2f}')
    print(f"{'Amplitude':<30} {amplitude:>6.2f}\n")
# Out:
# CENTRO-OESTE
# Quantidade de dados               467
# Média Nota Redação             486.55
# Desvio Padrão Nota Redação      39.91
# Menor Nota Redação             337.78
# Maior Nota Redação             594.23
# Amplitude                      256.46
#
# NORDESTE
# Quantidade de dados              1794
# Média Nota Redação             485.73
# Desvio Padrão Nota Redação      42.47
# Menor Nota Redação             320.00
# Maior Nota Redação             622.44
# Amplitude                      302.44
#
# NORTE
# Quantidade de dados               450
# Média Nota Redação             470.63
# Desvio Padrão Nota Redação      36.70
# Menor Nota Redação             330.94
# Maior Nota Redação             568.33
# Amplitude                      237.40
#
# SUDESTE
# Quantidade de dados              1668
# Média Nota Redação             517.26
# Desvio Padrão Nota Redação      42.09
# Menor Nota Redação             356.67
# Maior Nota Redação             646.36
# ...
